# %% [markdown]
# # Processing Layer - TCS Stock Prediction
#
# This notebook processes and engineers features for each time horizon:
# - 1D, 5D, 1M, 6M, 1Y, 5Y

# %%
import pandas as pd
import numpy as np
import os
from scipy.stats import zscore

os.makedirs('data/processed', exist_ok=True)

# %% [markdown]
# ## Feature Engineering Function

# %%
def engineer_features(df):
    df = df.copy()

    # Detect 'Date' or 'Datetime' column
    if 'Date' in df.columns:
        df['Date'] = pd.to_datetime(df['Date']).dt.date
    elif 'Datetime' in df.columns:
        df['Date'] = pd.to_datetime(df['Datetime']).dt.date
    else:
        raise ValueError("No 'Date' or 'Datetime' column found in DataFrame.")
    
    date_series = df['Date']
    # Essential numeric columns
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']].dropna()
    df = df.apply(pd.to_numeric, errors='coerce')

    # Interpolate and remove outliers
    df.interpolate(method='linear', inplace=True)
    df.dropna(inplace=True)
    z_cols = ['Close', 'Volume', 'Open', 'High', 'Low']
    df = df[(np.abs(zscore(df[z_cols])) < 3).all(axis=1)]

    df['Date'] = date_series.loc[df.index]

    # ──────────────────────────────────────
    # 📊 Technical & Statistical Features

    df['Price'] = (df['High'] + df['Low']) / 2

    # Moving Averages
    df['MA20'] = df['Close'].rolling(20).mean()
    df['MA50'] = df['Close'].rolling(50).mean()

    # RSI
    delta = df['Close'].diff()
    gain = delta.clip(lower=0).rolling(14).mean()
    loss = -delta.clip(upper=0).rolling(14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))

    # MACD & Signal Line
    ema12 = df['Close'].ewm(span=12, adjust=False).mean()
    ema26 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = ema12 - ema26
    df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

    # Bollinger Bands
    rolling_mean = df['Close'].rolling(20).mean()
    rolling_std = df['Close'].rolling(20).std()
    df['BB_High'] = rolling_mean + (rolling_std * 2)
    df['BB_Low'] = rolling_mean - (rolling_std * 2)

    # Lags
    for i in range(1, 8):
        df[f'Lag_{i}'] = df['Close'].shift(i)

    # Return & Volatility
    df['Return_1d'] = df['Close'].pct_change()
    df['Return_5d'] = df['Close'].pct_change(5)
    df['Volatility_5d'] = df['Close'].rolling(5).std()

    # New: price change & volume trend
    df['Price_Change'] = df['Close'] - df['Open']
    df['Volume_Change'] = df['Volume'].pct_change()

    # Target
    df['Tomorrow'] = df['Close'].shift(-1)

    # Final cleanup
    df.dropna(inplace=True)
    # Add 'Date' column if available
    cols = ['Date'] + [col for col in df.columns if col != 'Date']
    return df

# %% [markdown]
# ## Process All Time Horizons

# %%
files = {
    '1d': 'data/tcs_1d_1min.csv',
    '5d': 'data/tcs_5d_30min.csv',
    '1m': 'data/tcs_1m_1d.csv',
    '6m': 'data/tcs_6m_1d.csv',
    '1y': 'data/tcs_1y_1d.csv',
    '5y': 'data/tcs_5y_7d.csv'
}

for tag, path in files.items():
    print(f"Processing: {tag.upper()} data from {path}")
    df = pd.read_csv(path)
    processed = engineer_features(df)
    processed.to_csv(f'data/processed/tcs_{tag}_features.csv', index=False)
    print(processed.head())
# Out:
# Processing: 1D data from data/tcs_1d_1min.csv
#            Open         High          Low        Close   Volume        Date  \
# 85  3236.300049  3239.300049  3236.300049  3237.899902   2176.0  2025-12-18
# 86  3239.000000  3244.000000  3239.000000  3243.600098  16372.0  2025-12-18
# 87  3243.600098  3244.000000  3242.899902  3243.500000   2743.0  2025-12-18
# 88  3243.800049  3243.800049  3241.899902  3241.899902   1609.0  2025-12-18
# 89  3242.500000  3243.899902  3242.100098  3242.800049   4216.0  2025-12-18
#
#           Price         MA20         MA50        RSI  ...        Lag_4  \
# 85  3237.800049  3237.994983  3239.197983  38.028024  ...  3237.000000
# 86  3241.500000  3238.154993  3239.331987  57.513124  ...  3235.000000
# 87  3243.449951  3238.364990  3239.401987  64.912055  ...  3236.500000
# 88  3242.849976  3238.579980  3239.343984  59.357947  ...  3236.500000
# 89  3243.000000  3238.824988  3239.319985  60.416296  ...  3237.899902
#
#      Lag_5   Lag_6        Lag_7  Return_1d  Return_5d  Volatility_5d  \
# 85  3235.0  3236.5  3236.399902   0.000433   0.000896       1.052110
# 86  3237.0  3235.0  3236.500000   0.001760   0.002039       3.347429
# 87  3235.0  3237.0  3235.000000  -0.000031   0.002628       3.651065
# 88  3236.5  3235.0  3237.000000  -0.000493   0.001668       3.285151
# 89  3236.5  3236.5  3235.000000   0.000278   0.001947       2.358665
#
#     Price_Change  Volume_Change     Tomorrow
# 85      1.599854       0.948075  3243.600098
# 86      4.600098       6.523897  3243.500000
# 87     -0.100098      -0.832458  3241.899902
# 88     -1.900146      -0.413416  3242.800049
# 89      0.300049       1.620261  3243.500000
#
# [5 rows x 27 columns]
# Processing: 5D data from data/tcs_5d_30min.csv
#            Open         High          Low   Close    Volume        Date  \
# 52  3225.899902  3230.000000  3221.899902  3227.5  234101.0  2025-12-04
# 53  3227.500000  3232.500000  3226.000000  3228.5  492782.0  2025-12-04
# 54  3231.100098  3244.500000  3223.899902  3243.0   93132.0  2025-12-05
# 55  3242.899902  3247.199951  3239.300049  3245.0  182167.0  2025-12-05
# 56  3245.000000  3249.899902  3240.000000  3242.5  179360.0  2025-12-05
#
#           Price         MA20         MA50        RSI  ...        Lag_4  \
# 52  3225.949951  3212.650000  3168.664004  73.951484  ...  3235.399902
# 53  3229.250000  3214.475000  3170.354004  79.718765  ...  3233.800049
# 54  3234.199951  3216.105005  3172.536006  82.201793  ...  3225.100098
# 55  3243.250000  3218.455005  3174.646006  82.894802  ...  3226.000000
# 56  3244.949951  3221.630005  3176.816006  68.506577  ...  3227.500000
#
#           Lag_5        Lag_6        Lag_7  Return_1d  Return_5d  \
# 52  3238.199951  3241.500000  3240.500000   0.000465  -0.003304
# 53  3235.399902  3238.199951  3241.500000   0.000310  -0.002133
# 54  3233.800049  3235.399902  3238.199951   0.004491   0.002845
# 55  3225.100098  3233.800049  3235.399902   0.000617   0.006170
# 56  3226.000000  3225.100098  3233.800049  -0.000770   0.005115
#
#     Volatility_5d  Price_Change  Volume_Change  Tomorrow
# 52       4.714085      1.600098      -0.001552    3228.5
# 53       3.405435      1.000000       1.104997    3243.0
# 54       7.374060     11.899902      -0.811008    3245.0
# 55       9.199185      2.100098       0.956009    3242.5
# 56       8.548392     -2.500000      -0.015409    3258.5
#
# [5 rows x 27 columns]
# Processing: 1M data from data/tcs_1m_1d.csv
#            Open         High          Low        Close     Volume        Date  \
# 52  3038.666792  3053.511330  3004.793130  3007.781982  2626187.0  2025-09-08
# 53  3020.833326  3048.629557  3019.538108  3038.068848  2489301.0  2025-09-09
# 54  3045.042917  3111.096608  3042.054065  3098.443848  2079428.0  2025-09-10
# 55  3127.336119  3127.336119  3098.543603  3112.591064  2263446.0  2025-09-11
# 56  3132.317546  3137.000033  3109.403009  3121.756836  1447167.0  2025-09-12
#
#           Price         MA20         MA50        RSI  ...        Lag_4  \
# 52  3029.152230  3059.314771  3152.279482  50.892036  ...  3099.938232
# 53  3034.083833  3059.962354  3144.692593  53.588385  ...  3085.990234
# 54  3076.575337  3063.409497  3138.327100  51.293104  ...  3084.197021
# 55  3112.939861  3067.833008  3131.829521  52.394653  ...  3036.973145
# 56  3123.201521  3072.674951  3126.156680  59.645283  ...  3007.781982
#
#           Lag_5        Lag_6        Lag_7  Return_1d  Return_5d  \
# 52  3101.034180  3073.237793  3082.204346  -0.009612  -0.030071
# 53  3099.938232  3101.034180  3073.237793   0.010070  -0.019958
# 54  3085.990234  3099.938232  3101.034180   0.019873   0.004036
# 55  3084.197021  3085.990234  3099.938232   0.004566   0.009206
# 56  3036.973145  3084.197021  3085.990234   0.002945   0.027917
#
#     Volatility_5d  Price_Change  Volume_Change     Tomorrow
# 52      38.950999    -30.884810      -0.062764  3038.068848
# 53      33.754008     17.235522      -0.052123  3098.443848
# 54      37.292167     53.400930      -0.164654  3112.591064
# 55      44.649019    -14.745055       0.088495  3121.756836
# 56      50.071005    -10.560710      -0.360636  3100.336670
#
# [5 rows x 27 columns]
# Processing: 6M data from data/tcs_6m_1d.csv
#            Open         High          Low        Close     Volume        Date  \
# 53  3543.001060  3567.605234  3517.806289  3554.023682  2051315.0  2025-03-07
# 54  3549.398006  3564.751106  3525.876513  3532.814697  1004626.0  2025-03-10
# 55  3501.666002  3531.929136  3481.638109  3518.692139  1995450.0  2025-03-11
# 56  3508.555099  3512.737808  3431.642549  3450.686035  3174167.0  2025-03-12
# 57  3446.848012  3468.499685  3428.936221  3455.459473  1693004.0  2025-03-13
#
#           Price         MA20         MA50        RSI  ...        Lag_4  \
# 53  3542.705762  3726.924548  3903.001094  24.997936  ...  3437.744385
# 54  3545.313809  3702.659900  3893.078276  20.976997  ...  3476.126953
# 55  3506.783622  3680.314392  3882.955151  21.556969  ...  3490.889404
# 56  3472.190179  3654.197058  3871.588848  20.235232  ...  3544.575684
# 57  3448.717953  3631.930286  3861.554980  24.349512  ...  3554.023682
#
#           Lag_5        Lag_6        Lag_7  Return_1d  Return_5d  \
# 53  3555.352051  3572.083008  3617.404053   0.002665  -0.000374
# 54  3437.744385  3555.352051  3572.083008  -0.005968   0.027655
# 55  3476.126953  3437.744385  3555.352051  -0.003998   0.012245
# 56  3490.889404  3476.126953  3437.744385  -0.019327  -0.011517
# 57  3544.575684  3490.889404  3476.126953   0.001383  -0.025142
#
#     Volatility_5d  Price_Change  Volume_Change     Tomorrow
# 53      48.559187     11.022622      -0.263842  3532.814697
# 54      34.269410    -16.583309      -0.510253  3518.692139
# 55      24.692109     17.026136       0.986262  3450.686035
# 56      41.023781    -57.869063       0.590702  3455.459473
# 57      46.725845      8.611461      -0.466630  3442.320801
#
# [5 rows x 27 columns]
# Processing: 1Y data from data/tcs_1y_1d.csv
#            Open         High          Low        Close     Volume        Date  \
# 52  3881.502085  3937.838770  3855.434386  3923.134033  2688905.0  2024-03-07
# 53  3904.418784  3965.529765  3904.418784  3936.263428  2304068.0  2024-03-11
# 54  3936.263259  4039.006185  3935.021662  4003.007812  4039801.0  2024-03-12
# 55  4015.182312  4049.557238  3945.382022  3961.710205  2837260.0  2024-03-13
# 56  3965.959997  4034.279984  3901.554559  4017.665527  2919608.0  2024-03-14
#
#           Price         MA20         MA50        RSI  ...        Lag_4  \
# 52  3896.636578  3899.654150  3752.857285  48.460229  ...  3909.527588
# 53  3934.974275  3899.112244  3759.599727  51.474723  ...  3896.493408
# 54  3987.013924  3902.528235  3767.380264  62.913523  ...  3830.990479
# 55  3997.469630  3902.504370  3774.549146  62.503994  ...  3880.833984
# 56  3967.917271  3907.636731  3782.960405  60.163683  ...  3923.134033
#
#           Lag_5        Lag_6        Lag_7  Return_1d  Return_5d  \
# 52  3910.243652  3933.017090  3919.123535   0.010900   0.003297
# 53  3909.527588  3910.243652  3933.017090   0.003347   0.006839
# 54  3896.493408  3909.527588  3910.243652   0.016956   0.027336
# 55  3830.990479  3896.493408  3909.527588  -0.010317   0.034122
# 56  3880.833984  3830.990479  3896.493408   0.014124   0.035258
#
#     Volatility_5d  Price_Change  Volume_Change     Tomorrow
# 52      35.606252     41.631948       0.541623  3936.263428
# 53      41.181629     31.844644      -0.143120  4003.007812
# 54      64.203716     66.744554       0.753334  3961.710205
# 55      45.374713    -53.472107      -0.297673  4017.665527
# 56      41.083159     51.705531       0.029024  4028.789307
#
# [5 rows x 27 columns]
# Processing: 5Y data from data/tcs_5y_7d.csv
#            Open         High          Low        Close      Volume  \
# 54  3315.383699  3395.762110  3299.217792  3376.209473   7620892.0
# 55  3386.730582  3512.400776  3382.214941  3480.204346  10838679.0
# 56  3592.644437  3592.644437  3464.896981  3583.748535  19079572.0
# 57  3605.920315  3651.347713  3405.787216  3462.142334  18223318.0
# 58  3474.106589  3482.837003  3279.683368  3338.444580  15451074.0
#
#           Date        Price         MA20         MA50        RSI  ...  \
# 54  2021-12-27  3347.489951  3287.458447  3011.395601  47.316139  ...
# 55  2022-01-03  3447.307859  3305.373450  3028.680205  49.675947  ...
# 56  2022-01-10  3528.770709  3324.134448  3041.225884  57.773737  ...
# 57  2022-01-17  3528.567464  3329.574634  3054.771978  46.858842  ...
# 58  2022-01-24  3381.260185  3323.335901  3065.009922  58.143726  ...
#
#           Lag_4        Lag_5        Lag_6        Lag_7  Return_1d  Return_5d  \
# 54  3287.793213  3112.947754  3139.002930  3184.476074   0.018374   0.084570
# 55  3284.497070  3287.793213  3112.947754  3139.002930   0.030802   0.058523
# 56  3237.127930  3284.497070  3287.793213  3112.947754   0.029752   0.091110
# 57  3315.293701  3237.127930  3284.497070  3287.793213  -0.033933   0.069511
# 58  3376.209473  3315.293701  3237.127930  3284.497070  -0.035729   0.006983
#
#     Volatility_5d  Price_Change  Volume_Change     Tomorrow
# 54      50.950601     60.825774      -0.228687  3480.204346
# 55      93.852454     93.473764       0.422232  3583.748535
# 56     136.431044     -8.895902       0.760323  3462.142334
# 57     102.870386   -143.777981      -0.044878  3338.444580
# 58      95.943926   -135.662009      -0.152126  3451.398193
#
# [5 rows x 27 columns]
